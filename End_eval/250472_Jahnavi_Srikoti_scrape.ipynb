# %% [markdown]
# <a href="https://colab.research.google.com/github/jahnavisrikoti/DataDiction/blob/main/250472_Jahnavi_Srikoti_scrape.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install beautifulsoup4 lxml pandas openpyxl

import pandas as pd
from bs4 import BeautifulSoup
import os

html_filename = "dataset.html"

# %%
# Read HTML
with open(html_filename, "r", encoding="utf-8") as f:
    html_content = f.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-238908914.py in <cell line: 0>()
#       1 # Read HTML
# ----> 2 with open(html_filename, "r", encoding="utf-8") as f:
#       3     html_content = f.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dataset.html'

# %%
# Parse with BeautifulSoup
soup = BeautifulSoup(html_content, "html.parser")
tables = soup.find_all("table")

# %%
# Convert first table to DataFrame
table_html = str(tables[0])
df_list = pd.read_html(table_html)
df = df_list[0]

print(f" SHAPE: {df.shape}")
print(" COLUMNS:", df.columns.tolist())
print("\n FIRST 5 ROWS:")
print(df.head())

# %%
csv_name = "addiction_data.csv"
df.to_csv(csv_name, index=False)
